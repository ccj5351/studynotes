# %% [markdown]
# # Topic 1: Depth-First Search - DFS

# %% [markdown]
# ## What DFS can do: A DFS traversal graph G:
# - Visits all the edges of G
# - Determines whether G is connected
# - Computes the connected components of G
# - Computes a spannin forest of G
# - Find and report a path between two given vertices;
# - Find a cycle in the graph
#
#
# ## Basics:
#
# - DFS on a graph with $V$ vertices and $E$ edges takes $O(V+E)$ time. Recall that $\sum_v deg(v) = 2E$.

# %% [markdown]
# ## DFS Algorithm
#
# <div align="center"><img src="../files/dfs.png" width="700"/></div>
#
# `DFS大法:`
# ```
# DFS(G,v)
# 起于新点
# 置其为旧
# 遍历通径
# 择新探之
# 遇新递归
# 遇旧撤回
# ```

# %% [markdown]
# ## One Example:
# <img src="../files/dfs-exam1.png" alt="drawing" width="500"/>
# <img src="../files/dfs-exam2.png" alt="drawing" width="500"/>

# %% [markdown]
# ## Path Finding
#
# - find a path between two given vertices u an z;
# - Use a stack S to keep track of the path between the start vertex and the current vertex
#
# ```
# Algorithm pathDFS(G,v,z)
#   setLabel (v, VISITED)
#   S.push(v)
#   if v == z
#      return S.elements()
#   for all e in G.incidentEdges(v)
#      if getLabel(e) == UNEXPLORED # for edge
#          w <-- opposite(v, e)
#          if getLabel(w) == UNXEPLORED
#             setLabel(e, DISCOVERY)
#             S.push(e)
#             pathDFS(G, w, z)
#             S.pop() # e gets poped!
#          ese
#             setLabel(e, BACK)
#   S.pop() # v gets popped!
# ```

# %% [markdown]
# - Shown as below:
#
# <img src="../files/dfs_path_1.png" alt="drawing" width="350"/>

# %% [markdown]
# ## Cycle Finding
# - use a `stack S` to keep track of the path between the start vertex and the current vertex
# - As soon as a `back` edge (v, w) is encountered, we return the `cycle` as the protion of the stack from the top to vertex $w$
# - Shown as below:
#
#
# <img src="../files/dfs_cyclepath.png" alt="drawing" width="350"/>
